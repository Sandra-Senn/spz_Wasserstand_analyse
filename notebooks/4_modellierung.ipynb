# %% [markdown]
# # Vorhersage

# %% [markdown]
# ## Vorhersage

# %% [markdown]
# ## Bedingte Vorhersagen

# %% [markdown]
# ##  Weiterverwendung in anderen Modellen

# %% [markdown]
# ## Extremwertanalysen
